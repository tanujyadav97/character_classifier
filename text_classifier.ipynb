# %%
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
filename= open('text8')
def read_data(filename):
    data = tf.compat.as_str(filename.read()).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5236, 3082, 12, 6, 195, 2, 3136, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'term', 'anarchism', 'as', 'term', 'originated', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.140042
# Nearest to use: administer, avionics, wilkinson, syndicates, defenseless, iota, koffice, specifying,
# Nearest to th: vicar, myron, foundations, wavelet, wufei, arrays, periods, emphasises,
# Nearest to new: force, zanu, dundee, pacino, joual, sergei, kiang, unthinkable,
# Nearest to but: transfiguration, blas, albrecht, metalwork, girdle, viterbo, veracruz, shifts,
# Nearest to which: suppose, boeotia, operates, discriminant, lt, abeda, promoters, freyr,
# Nearest to its: ghc, tco, fewest, crossfire, digested, immersed, necessities, aunt,
# Nearest to so: kana, summing, cacm, voc, verbs, argument, masovia, associated,
# Nearest to eight: cliath, hemphill, humanities, kabbalistic, nter, vci, thinning, luminiferous,
# Nearest to will: engravers, clues, pennant, inviscid, floor, suburbs, seq, vassar,
# Nearest to than: verizon, untold, turner, embryo, followers, depending, visualized, sled,
# Nearest to called: lim, interim, anders, barak, fuji, homesick, tangled, wire,
# Nearest to his: chem, referendum, gianfranco, amalgam, uterine, activate, fenway, strat,
# Nearest to can: bde, espn, kritik, attacks, intercontinental, kuala, delinquency, wiesbaden,
# Nearest to up: mjt, exchangeable, irenaeus, enabling, rose, charge, booed, mies,
# Nearest to not: failings, multipurpose, incumbent, connections, yuan, xiii, udi, posters,
# Nearest to two: discards, legitimate, orphaned, rockwell, germans, vastly, zoroastrianism, ellefson,
# Average loss at step 2000: 4.374654
# Average loss at step 4000: 3.861059
# Average loss at step 6000: 3.785494
# Average loss at step 8000: 3.681828
# Average loss at step 10000: 3.619832
# Nearest to use: opinion, wilkinson, defenseless, syndicates, apprentices, shaken, dipped, diocletian,
# Nearest to th: wavelet, one, four, myron, emphasises, vogt, tammy, seven,
# Nearest to new: dundee, bill, force, smokeless, peirce, disgusted, fragmented, car,
# Nearest to but: it, although, asp, feodor, letters, while, is, are,
# Nearest to which: this, also, that, it, excrement, guideline, heh, coronado,
# Nearest to its: their, the, his, ghc, socialist, lynn, semen, negev,
# Nearest to so: kana, amato, gerry, charity, barking, ustawa, voc, sofa,
# Nearest to eight: nine, six, five, seven, four, three, zero, two,
# Nearest to will: would, floor, liberalize, can, engravers, loretta, varuna, ingram,
# Nearest to than: salinas, counterparts, aloof, coffey, amplification, tsunamis, turner, tacoma,
# Nearest to called: barak, english, lim, wire, rhombic, dreadnoughts, secretion, anders,
# Nearest to his: their, the, its, s, her, purposefully, adversaries, injections,
# Nearest to can: would, may, might, must, cannot, will, championing, bde,
# Nearest to up: enabling, irenaeus, exchangeable, diatomaceous, mjt, similar, yerushalmi, unencumbered,
# Nearest to not: also, it, they, udi, often, to, still, bibliotheca,
# Nearest to two: three, four, nine, five, six, eight, zero, seven,
# Average loss at step 12000: 3.602978
# Average loss at step 14000: 3.569922
# Average loss at step 16000: 3.409659
# Average loss at step 18000: 3.453723
# Average loss at step 20000: 3.540915
# Nearest to use: opinion, wilkinson, apprentices, syndicates, specifying, defenseless, dont, glc,
# Nearest to th: fifth, myron, wavelet, isomers, arrays, vogt, blinds, deutschland,
# Nearest to new: unthinkable, tidy, atypical, bill, criterion, fragmented, usurped, peirce,
# Nearest to but: however, and, although, that, if, feodor, does, which,
# Nearest to which: this, that, also, it, who, there, however, heh,
# Nearest to its: their, the, his, stench, our, some, causation, puzo,
# Nearest to so: charity, kana, amato, sofa, gen, voc, daigo, ustawa,
# Nearest to eight: six, nine, seven, four, five, three, two, zero,
# Nearest to will: would, can, may, could, to, might, liberalize, must,
# Nearest to than: or, aloof, ev, sited, coffey, pictured, counterparts, tacoma,
# Nearest to called: barak, secretion, dreadnoughts, bandage, agincourt, equipment, used, donegal,
# Nearest to his: their, her, its, the, injections, this, trash, censorial,
# Nearest to can: may, would, will, must, might, could, cannot, should,
# Nearest to up: enabling, irenaeus, similar, diatomaceous, tissue, willamette, yerushalmi, charge,
# Nearest to not: also, still, it, to, they, thrift, often, be,
# Nearest to two: three, four, six, five, eight, one, seven, zero,
# Average loss at step 22000: 3.500446
# Average loss at step 24000: 3.488239
# Average loss at step 26000: 3.482325
# Average loss at step 28000: 3.482407
# Average loss at step 30000: 3.500857
# Nearest to use: opinion, apprentices, corresponding, elites, laia, shaken, defenseless, picatinny,
# Nearest to th: seven, myron, fifth, cambridge, rd, deutschland, negatives, bc,
# Nearest to new: yamaha, fragmented, tidy, peirce, birley, melanie, current, bill,
# Nearest to but: however, although, and, do, feodor, while, does, though,
# Nearest to which: this, that, it, what, who, but, also, rigging,
# Nearest to its: their, his, the, our, some, earths, her, many,
# Nearest to so: gen, voc, bose, kana, industries, swordsmiths, charity, amato,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to will: would, can, may, could, might, must, cannot, should,
# Nearest to than: ev, or, sited, aloof, joaquin, coffey, levites, fiddler,
# Nearest to called: barak, used, interrogators, equipment, dreadnoughts, bandage, purer, secretion,
# Nearest to his: their, her, its, s, the, trash, your, my,
# Nearest to can: may, would, could, will, might, must, cannot, should,
# Nearest to up: irenaeus, down, saddened, respected, out, enabling, unencumbered, similar,
# Nearest to not: still, they, also, it, often, to, greaves, there,
# Nearest to two: four, one, three, five, seven, eight, six, nine,
# Average loss at step 32000: 3.501913
# Average loss at step 34000: 3.493984
# Average loss at step 36000: 3.452933
# Average loss at step 38000: 3.296963
# Average loss at step 40000: 3.431768
# Nearest to use: opinion, apprentices, shaken, defenseless, elites, dipped, corresponding, circumvented,
# Nearest to th: myron, fifth, rd, bc, vogt, melaka, joysticks, tammy,
# Nearest to new: tidy, birley, maecenas, marginalism, criterion, member, yamaha, reworking,
# Nearest to but: however, and, while, though, although, it, does, elaborate,
# Nearest to which: that, this, also, who, usually, there, these, what,
# Nearest to its: their, his, the, her, our, any, coexisted, your,
# Nearest to so: gen, too, voc, bose, swordsmiths, then, electrification, dal,
# Nearest to eight: nine, seven, six, four, five, three, two, zero,
# Nearest to will: would, can, could, may, must, might, should, cannot,
# Nearest to than: or, ev, sited, joaquin, ketones, fiddler, coffey, k,
# Nearest to called: interrogators, used, agincourt, afoul, like, named, dreadnoughts, secretion,
# Nearest to his: their, her, its, the, s, my, your, defensive,
# Nearest to can: may, could, will, would, must, might, cannot, should,
# Nearest to up: out, down, irenaeus, them, saddened, him, back, enabling,
# Nearest to not: still, they, also, it, often, always, almost, thrift,
# Nearest to two: three, four, six, five, seven, eight, one, zero,
# Average loss at step 42000: 3.433754
# Average loss at step 44000: 3.456308
# Average loss at step 46000: 3.451137
# Average loss at step 48000: 3.353731
# Average loss at step 50000: 3.387181
# Nearest to use: opinion, order, sasl, elites, shaken, apprentices, dipped, circumvented,
# Nearest to th: myron, fifth, rd, vogt, bc, serviced, eight, negatives,
# Nearest to new: birley, tidy, fragmented, marginalism, member, third, constituency, printer,
# Nearest to but: however, while, although, and, when, though, elaborate, which,
# Nearest to which: that, this, who, also, usually, still, there, often,
# Nearest to its: their, his, the, her, our, your, bootlegs, hector,
# Nearest to so: then, too, telegram, proves, thus, bose, enabled, exchanged,
# Nearest to eight: six, nine, seven, four, five, three, zero, one,
# Nearest to will: would, can, could, may, might, must, should, cannot,
# Nearest to than: or, much, sited, ev, ketones, guanosine, celebrates, but,
# Nearest to called: interrogators, used, afoul, named, raeder, cowboys, agincourt, buff,
# Nearest to his: their, her, its, the, my, your, whose, them,
# Nearest to can: may, could, will, would, must, might, should, cannot,
# Nearest to up: out, down, irenaeus, him, saddened, off, them, back,
# Nearest to not: still, generally, always, almost, they, now, often, usually,
# Nearest to two: three, one, six, four, five, seven, eight, nine,
# Average loss at step 52000: 3.434802
# Average loss at step 54000: 3.424632
# Average loss at step 56000: 3.438385
# Average loss at step 58000: 3.399877
# Average loss at step 60000: 3.393060
# Nearest to use: shaken, opinion, order, irrational, hologram, apprentices, calculation, ria,
# Nearest to th: myron, four, six, eight, bc, rd, fifth, tammy,
# Nearest to new: tasting, tidy, titans, birley, mumford, different, republican, marginalism,
# Nearest to but: however, and, although, while, though, which, when, since,
# Nearest to which: that, this, what, it, these, but, who, there,
# Nearest to its: their, his, the, her, your, whose, coexisted, smallholders,
# Nearest to so: then, too, telegram, if, thus, exchanged, proves, photons,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to will: would, could, can, may, must, might, should, cannot,
# Nearest to than: or, and, ev, much, ketones, sited, pommel, aloof,
# Nearest to called: used, raeder, known, afoul, interrogators, considered, named, looping,
# Nearest to his: her, their, its, my, your, whose, fugues, the,
# Nearest to can: may, could, would, will, must, might, cannot, should,
# Nearest to up: down, out, him, off, irenaeus, saddened, them, back,
# Nearest to not: still, now, they, there, usually, always, you, uncountable,
# Nearest to two: three, four, six, five, eight, one, seven, zero,
# Average loss at step 62000: 3.238675
# Average loss at step 64000: 3.259575
# Average loss at step 66000: 3.400386
# Average loss at step 68000: 3.398359
# Average loss at step 70000: 3.362075
# Nearest to use: opinion, shaken, form, elites, humane, irrational, branched, hologram,
# Nearest to th: myron, fifth, bc, four, one, eight, nineteenth, vogt,
# Nearest to new: tidy, accumulation, republican, fragmented, different, shades, birley, downwards,
# Nearest to but: however, although, which, and, that, though, snowfalls, while,
# Nearest to which: that, this, but, actually, usually, also, it, who,
# Nearest to its: their, his, the, her, your, whose, our, coexisted,
# Nearest to so: thus, telegram, then, exchanged, if, too, cryoprotectant, proves,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to will: would, could, may, must, can, should, might, cannot,
# Nearest to than: or, much, but, ketones, and, ev, tsunamis, while,
# Nearest to called: named, referred, raeder, known, interrogators, used, considered, afoul,
# Nearest to his: her, their, its, my, your, our, whose, censorial,
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to up: down, out, off, back, irenaeus, him, saddened, them,
# Nearest to not: now, always, still, never, generally, thrift, usually, you,
# Nearest to two: three, six, four, one, seven, five, eight, zero,
# Average loss at step 72000: 3.373057
# Average loss at step 74000: 3.344773
# Average loss at step 76000: 3.320743
# Average loss at step 78000: 3.354025
# Average loss at step 80000: 3.376671
# Nearest to use: cause, shaken, opinion, sasl, consist, form, elites, failure,
# Nearest to th: fifth, five, eight, myron, rd, bc, grasso, vogt,
# Nearest to new: tidy, reductio, accumulation, jair, different, printer, alterations, lambar,
# Nearest to but: however, although, while, and, snowfalls, than, ix, though,
# Nearest to which: that, this, usually, also, actually, what, based, but,
# Nearest to its: their, his, her, the, your, our, whose, coexisted,
# Nearest to so: thus, later, attended, too, then, if, before, indeed,
# Nearest to eight: six, nine, seven, five, four, three, zero, two,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to than: or, much, ketones, but, while, far, ev, lycanthropy,
# Nearest to called: referred, named, considered, known, used, afoul, quoted, comparatively,
# Nearest to his: her, their, its, my, your, the, our, gere,
# Nearest to can: could, may, will, would, must, might, cannot, should,
# Nearest to up: down, out, off, them, back, him, saddened, irenaeus,
# Nearest to not: still, generally, always, usually, often, sometimes, it, now,
# Nearest to two: three, four, six, five, one, seven, eight, zero,
# Average loss at step 82000: 3.402985
# Average loss at step 84000: 3.413508
# Average loss at step 86000: 3.389560
# Average loss at step 88000: 3.355197
# Average loss at step 90000: 3.366927
# Nearest to use: opinion, shaken, elites, failure, list, alteration, cause, consist,
# Nearest to th: seven, fifth, rd, eight, bc, one, joysticks, bce,
# Nearest to new: tidy, different, accumulation, lambar, obfuscation, jair, reductio, techs,
# Nearest to but: however, although, and, though, while, which, he, until,
# Nearest to which: that, this, also, usually, actually, what, but, based,
# Nearest to its: their, his, her, the, our, whose, your, gere,
# Nearest to so: thus, later, too, attended, before, then, indeed, if,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# Nearest to will: would, could, must, can, might, should, may, cannot,
# Nearest to than: much, ketones, or, episcopalians, necker, lycanthropy, joaquin, even,
# Nearest to called: referred, named, used, known, considered, whispering, quoted, miyazaki,
# Nearest to his: her, their, its, your, my, the, our, whose,
# Nearest to can: could, may, will, must, might, would, should, cannot,
# Nearest to up: out, down, off, them, back, him, humayun, rebounded,
# Nearest to not: still, generally, now, we, incorrect, they, always, often,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Average loss at step 92000: 3.402761
# Average loss at step 94000: 3.253241
# Average loss at step 96000: 3.363251
# Average loss at step 98000: 3.242066
# Average loss at step 100000: 3.356564
# Nearest to use: form, failure, humane, opinion, illustrate, cause, elites, think,
# Nearest to th: fifth, bc, myron, rd, joysticks, grasso, nd, third,
# Nearest to new: different, tidy, accumulation, reductio, obfuscation, ischemia, jair, gallifrey,
# Nearest to but: however, although, and, though, which, while, crassus, occur,
# Nearest to which: that, this, usually, actually, but, however, what, typically,
# Nearest to its: their, his, the, her, our, whose, your, coexisted,
# Nearest to so: thus, then, too, later, if, when, indeed, faster,
# Nearest to eight: nine, seven, six, four, five, zero, three, two,
# Nearest to will: would, could, must, can, should, might, may, cannot,
# Nearest to than: or, much, ketones, tsunamis, episcopalians, sedative, while, trembling,
# Nearest to called: referred, named, known, used, whispering, quoted, interrogators, considered,
# Nearest to his: her, their, my, your, its, the, s, our,
# Nearest to can: could, may, must, would, will, might, cannot, should,
# Nearest to up: out, down, off, him, them, back, humayun, insured,
# Nearest to not: still, generally, never, almost, now, they, always, also,
# Nearest to two: six, four, five, three, one, eight, seven, nine,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
